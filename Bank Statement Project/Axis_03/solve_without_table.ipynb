# %%
import pandas as pd
import numpy as np
import re
import tabula
import camelot
import pdfminer
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
try:
    from cStringIO import StringIO
except ImportError:
    from io import StringIO 
import matplotlib.pyplot as plt

# %%
tables=camelot.read_pdf("axis03.pdf",flavor='stream' ,pages = "all",edge_tol=500)            
if len(tables) !=0 :
    df=pd.DataFrame();    tmp=pd.DataFrame(); 
    for i in range(len(tables)) :
        tmp=tables[i].df  
        df=pd.concat([df,tmp]).drop_duplicates(keep='first').reset_index(drop=True)

# %%
df.to_csv("error1.csv",index=0)

# %%
tmp=tables[2].df
tmp
# Out:
#                                                     0        1         2  \
# 0      Tran Date\nValue Date\nTransaction Particulars  Chq No.    Amount
# 1                                   OPENING BALANCE :
# 2
# 3   14-01-2019\n14-01-2019\nEDC/00053-00053-/M0370...            1001.90
# 4
# 5
# 6   14-01-2019\n14-01-2019\nIMPS/P2A/901412924696/...             497.00
# 7
# 8
# 9   14-01-2019\n14-01-2019\nIMPS/P2A/901412927199/...             400.00
# 10
# 11
# 12  14-01-2019\n14-01-2019\nIMPS/P2A/901412321960/...           50005.90
# 13
# 14
# 15  15-01-2019\n15-01-2019\nECOM PUR/PAYTM/Noida/1...             150.00
# 16
# 17                                   BY CASH DEPOSIT-
# 18                             17-01-2019\n17-01-2019            1000.00
# 19                 BNA/DPRH329801/6971/170119/SOUTH D
# 20
# 21  17-01-2019\n17-01-2019\nIMPS/P2A/901713217651/...            1002.95
# 22
# 23
# 24  21-01-2019\n21-01-2019\nEDC/00054-00054-/M0370...            2403.49
# 25
# 26
# 27  22-01-2019\n22-01-2019\nEDC/00055-00055-/M0370...            1426.82
# 28
# 29
# 30  22-01-2019\n22-01-2019\nECOM PUR/PAYTM/1204770...             400.00
# 31
# 32                                   BY CASH DEPOSIT-
# 33                             23-01-2019\n23-01-2019           24500.00
# 34                 BNA/DPRH329801/8113/230119/SOUTH D
# 35                                   BY CASH DEPOSIT-
# 36                             23-01-2019\n23-01-2019             500.00
# 37                 BNA/DPRH329801/8115/230119/SOUTH D
# 38
# 39  24-01-2019\n24-01-2019\nECOM PUR/PTM*PAYTM/NOI...            7000.00
# 40
# 41
# 42  28-01-2019\n28-01-2019\nEDC/00056-00056-/M0370...            1957.98
# 43
# 44                                   BY CASH DEPOSIT-
# 45                             28-01-2019\n28-01-2019           11500.00
# 46                 BNA/DPRH329801/8913/280119/SOUTH D
#
#         3         4              5
# 0   DR|CR   Balance    Branch Name
# 1          25184.55
# 2                              ATM
# 3      CR  49324.09  RECONCILATION
# 4                           CENTRE
# 5                       ZAMROODPUR
# 6      CR  49821.09
# 7                           DEL DL
# 8                       ZAMROODPUR
# 9      CR  50221.09
# 10                          DEL DL
# 11                      ZAMROODPUR
# 12     DR    215.19
# 13                          DEL DL
# 14                      ZAMROODPUR
# 15     DR     65.19
# 16                          DEL DL
# 17                      ZAMROODPUR
# 18     CR   1065.19
# 19                          DEL DL
# 20                      ZAMROODPUR
# 21     DR     62.24
# 22                          DEL DL
# 23                             ATM
# 24     CR   2465.73  RECONCILATION
# 25                          CENTRE
# 26                             ATM
# 27     CR   3892.55  RECONCILATION
# 28                          CENTRE
# 29                      ZAMROODPUR
# 30     DR   3492.55
# 31                          DEL DL
# 32                      ZAMROODPUR
# 33     CR  27992.55
# 34                          DEL DL
# 35                      ZAMROODPUR
# 36     CR  28492.55
# 37                          DEL DL
# 38                      ZAMROODPUR
# 39     DR  21492.55
# 40                          DEL DL
# 41                             ATM
# 42     CR  23450.53  RECONCILATION
# 43                          CENTRE
# 44                      ZAMROODPUR
# 45     CR  34950.53
# 46                          DEL DL

# %%
idx=[ c for c in tmp[tmp.apply(lambda row: row.astype(str).str.lower().str.contains('balance').any(), axis=1) ==True].index if c in tmp[tmp.apply(lambda row: row.astype(str).str.lower().str.contains('date').any(), axis=1) ==True].index ][0]
tmp.columns=tmp.iloc[idx] ; tmp=tmp.iloc[idx+1:,:] ; tmp.reset_index(drop=True,inplace=True) 
print("Columns:",tmp.columns)
# Out:
# Columns: Index(['Tran Date\nValue Date\nTransaction Particulars', 'Chq No.', 'Amount',
#        'DR|CR', 'Balance', 'Branch Name'],
#       dtype='object', name=0)

# %%
if tmp.columns[0] == 'Tran Date\nValue Date\nTransaction Particulars':
    print("true")
# Out:
# true

# %%
tmp=tmp[~tmp.index.isin(tmp[tmp.apply(lambda row: row.astype(str).str.lower().str.contains('page:|account status|total|reason for return|inward clg|opening balance|statement of a/c').any(), axis=1) ==True].index)]
tmp=pd.DataFrame(tmp.T.drop_duplicates().T)
tmp.drop(tmp.nunique(dropna=False)[(tmp.nunique(dropna=False) == 1)].index, axis=1,inplace=True)

# %%
tmp.columns = ["A","B","C","D","E"]

# %%
# tmp.head()

# %%
# tmp.A

# %%
tmp1 = pd.DataFrame(tmp.A.str.split('\n',2).tolist(),columns=["Z1", "Z2", "Z3"])

# %%
tmp1
# Out:
#                                     Z1          Z2  \
# 0                                             None
# 1                           14-01-2019  14-01-2019
# 2                                             None
# 3                                             None
# 4                           14-01-2019  14-01-2019
# 5                                             None
# 6                                             None
# 7                           14-01-2019  14-01-2019
# 8                                             None
# 9                                             None
# 10                          14-01-2019  14-01-2019
# 11                                            None
# 12                                            None
# 13                          15-01-2019  15-01-2019
# 14                                            None
# 15                    BY CASH DEPOSIT-        None
# 16                          17-01-2019  17-01-2019
# 17  BNA/DPRH329801/6971/170119/SOUTH D        None
# 18                                            None
# 19                          17-01-2019  17-01-2019
# 20                                            None
# 21                                            None
# 22                          21-01-2019  21-01-2019
# 23                                            None
# 24                                            None
# 25                          22-01-2019  22-01-2019
# 26                                            None
# 27                                            None
# 28                          22-01-2019  22-01-2019
# 29                                            None
# 30                    BY CASH DEPOSIT-        None
# 31                          23-01-2019  23-01-2019
# 32  BNA/DPRH329801/8113/230119/SOUTH D        None
# 33                    BY CASH DEPOSIT-        None
# 34                          23-01-2019  23-01-2019
# 35  BNA/DPRH329801/8115/230119/SOUTH D        None
# 36                                            None
# 37                          24-01-2019  24-01-2019
# 38                                            None
# 39                                            None
# 40                          28-01-2019  28-01-2019
# 41                                            None
# 42                    BY CASH DEPOSIT-        None
# 43                          28-01-2019  28-01-2019
# 44  BNA/DPRH329801/8913/280119/SOUTH D        None
#
#                                                   Z3
# 0                                               None
# 1                  EDC/00053-00053-/M037011032984700
# 2                                               None
# 3                                               None
# 4   IMPS/P2A/901412924696/919971624523/INETIMPS00073
# 5                                               None
# 6                                               None
# 7   IMPS/P2A/901412927199/919971624523/MOBUA01304940
# 8                                               None
# 9                                               None
# 10   IMPS/P2A/901412321960/0831010104411UTBI0MBZC45/
# 11                                              None
# 12                                              None
# 13                 ECOM PUR/PAYTM/Noida/150119/10:25
# 14                                              None
# 15                                              None
# 16                                              None
# 17                                              None
# 18                                              None
# 19     IMPS/P2A/901713217651/62246765390SBIN0001078/
# 20                                              None
# 21                                              None
# 22                 EDC/00054-00054-/M037011032984700
# 23                                              None
# 24                                              None
# 25                 EDC/00055-00055-/M037011032984700
# 26                                              None
# 27                                              None
# 28            ECOM PUR/PAYTM/1204770770/220119/13:26
# 29                                              None
# 30                                              None
# 31                                              None
# 32                                              None
# 33                                              None
# 34                                              None
# 35                                              None
# 36                                              None
# 37             ECOM PUR/PTM*PAYTM/NOIDA/240119/17:50
# 38                                              None
# 39                                              None
# 40                 EDC/00056-00056-/M037011032984700
# 41                                              None
# 42                                              None
# 43                                              None
# 44                                              None

# %%
tmp1.replace(r'^\s*$', np.nan, regex=True, inplace=True)
tmp1.fillna(value=pd.np.nan, inplace=True)
# match = re.search(r'(\d+-\d+-\d+)',i)
# match.group(1)

# %%
tmp1
# Out:
#                                     Z1          Z2  \
# 0                                  NaN         NaN
# 1                           14-01-2019  14-01-2019
# 2                                  NaN         NaN
# 3                                  NaN         NaN
# 4                           14-01-2019  14-01-2019
# 5                                  NaN         NaN
# 6                                  NaN         NaN
# 7                           14-01-2019  14-01-2019
# 8                                  NaN         NaN
# 9                                  NaN         NaN
# 10                          14-01-2019  14-01-2019
# 11                                 NaN         NaN
# 12                                 NaN         NaN
# 13                          15-01-2019  15-01-2019
# 14                                 NaN         NaN
# 15                    BY CASH DEPOSIT-         NaN
# 16                          17-01-2019  17-01-2019
# 17  BNA/DPRH329801/6971/170119/SOUTH D         NaN
# 18                                 NaN         NaN
# 19                          17-01-2019  17-01-2019
# 20                                 NaN         NaN
# 21                                 NaN         NaN
# 22                          21-01-2019  21-01-2019
# 23                                 NaN         NaN
# 24                                 NaN         NaN
# 25                          22-01-2019  22-01-2019
# 26                                 NaN         NaN
# 27                                 NaN         NaN
# 28                          22-01-2019  22-01-2019
# 29                                 NaN         NaN
# 30                    BY CASH DEPOSIT-         NaN
# 31                          23-01-2019  23-01-2019
# 32  BNA/DPRH329801/8113/230119/SOUTH D         NaN
# 33                    BY CASH DEPOSIT-         NaN
# 34                          23-01-2019  23-01-2019
# 35  BNA/DPRH329801/8115/230119/SOUTH D         NaN
# 36                                 NaN         NaN
# 37                          24-01-2019  24-01-2019
# 38                                 NaN         NaN
# 39                                 NaN         NaN
# 40                          28-01-2019  28-01-2019
# 41                                 NaN         NaN
# 42                    BY CASH DEPOSIT-         NaN
# 43                          28-01-2019  28-01-2019
# 44  BNA/DPRH329801/8913/280119/SOUTH D         NaN
#
#                                                   Z3
# 0                                                NaN
# 1                  EDC/00053-00053-/M037011032984700
# 2                                                NaN
# 3                                                NaN
# 4   IMPS/P2A/901412924696/919971624523/INETIMPS00073
# 5                                                NaN
# 6                                                NaN
# 7   IMPS/P2A/901412927199/919971624523/MOBUA01304940
# 8                                                NaN
# 9                                                NaN
# 10   IMPS/P2A/901412321960/0831010104411UTBI0MBZC45/
# 11                                               NaN
# 12                                               NaN
# 13                 ECOM PUR/PAYTM/Noida/150119/10:25
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19     IMPS/P2A/901713217651/62246765390SBIN0001078/
# 20                                               NaN
# 21                                               NaN
# 22                 EDC/00054-00054-/M037011032984700
# 23                                               NaN
# 24                                               NaN
# 25                 EDC/00055-00055-/M037011032984700
# 26                                               NaN
# 27                                               NaN
# 28            ECOM PUR/PAYTM/1204770770/220119/13:26
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37             ECOM PUR/PTM*PAYTM/NOIDA/240119/17:50
# 38                                               NaN
# 39                                               NaN
# 40                 EDC/00056-00056-/M037011032984700
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN

# %%
tmp1["flag"] = tmp1["Z2"].astype(str)+tmp1["Z3"].astype(str)

# %%
tmp1
# Out:
#                                     Z1          Z2  \
# 0                                  NaN         NaN
# 1                           14-01-2019  14-01-2019
# 2                                  NaN         NaN
# 3                                  NaN         NaN
# 4                           14-01-2019  14-01-2019
# 5                                  NaN         NaN
# 6                                  NaN         NaN
# 7                           14-01-2019  14-01-2019
# 8                                  NaN         NaN
# 9                                  NaN         NaN
# 10                          14-01-2019  14-01-2019
# 11                                 NaN         NaN
# 12                                 NaN         NaN
# 13                          15-01-2019  15-01-2019
# 14                                 NaN         NaN
# 15                    BY CASH DEPOSIT-         NaN
# 16                          17-01-2019  17-01-2019
# 17  BNA/DPRH329801/6971/170119/SOUTH D         NaN
# 18                                 NaN         NaN
# 19                          17-01-2019  17-01-2019
# 20                                 NaN         NaN
# 21                                 NaN         NaN
# 22                          21-01-2019  21-01-2019
# 23                                 NaN         NaN
# 24                                 NaN         NaN
# 25                          22-01-2019  22-01-2019
# 26                                 NaN         NaN
# 27                                 NaN         NaN
# 28                          22-01-2019  22-01-2019
# 29                                 NaN         NaN
# 30                    BY CASH DEPOSIT-         NaN
# 31                          23-01-2019  23-01-2019
# 32  BNA/DPRH329801/8113/230119/SOUTH D         NaN
# 33                    BY CASH DEPOSIT-         NaN
# 34                          23-01-2019  23-01-2019
# 35  BNA/DPRH329801/8115/230119/SOUTH D         NaN
# 36                                 NaN         NaN
# 37                          24-01-2019  24-01-2019
# 38                                 NaN         NaN
# 39                                 NaN         NaN
# 40                          28-01-2019  28-01-2019
# 41                                 NaN         NaN
# 42                    BY CASH DEPOSIT-         NaN
# 43                          28-01-2019  28-01-2019
# 44  BNA/DPRH329801/8913/280119/SOUTH D         NaN
#
#                                                   Z3  \
# 0                                                NaN
# 1                  EDC/00053-00053-/M037011032984700
# 2                                                NaN
# 3                                                NaN
# 4   IMPS/P2A/901412924696/919971624523/INETIMPS00073
# 5                                                NaN
# 6                                                NaN
# 7   IMPS/P2A/901412927199/919971624523/MOBUA01304940
# 8                                                NaN
# 9                                                NaN
# 10   IMPS/P2A/901412321960/0831010104411UTBI0MBZC45/
# 11                                               NaN
# 12                                               NaN
# 13                 ECOM PUR/PAYTM/Noida/150119/10:25
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19     IMPS/P2A/901713217651/62246765390SBIN0001078/
# 20                                               NaN
# 21                                               NaN
# 22                 EDC/00054-00054-/M037011032984700
# 23                                               NaN
# 24                                               NaN
# 25                 EDC/00055-00055-/M037011032984700
# 26                                               NaN
# 27                                               NaN
# 28            ECOM PUR/PAYTM/1204770770/220119/13:26
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37             ECOM PUR/PTM*PAYTM/NOIDA/240119/17:50
# 38                                               NaN
# 39                                               NaN
# 40                 EDC/00056-00056-/M037011032984700
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
#
#                                                  flag
# 0                                              nannan
# 1         14-01-2019EDC/00053-00053-/M037011032984700
# 2                                              nannan
# 3                                              nannan
# 4   14-01-2019IMPS/P2A/901412924696/919971624523/I...
# 5                                              nannan
# 6                                              nannan
# 7   14-01-2019IMPS/P2A/901412927199/919971624523/M...
# 8                                              nannan
# 9                                              nannan
# 10  14-01-2019IMPS/P2A/901412321960/0831010104411U...
# 11                                             nannan
# 12                                             nannan
# 13        15-01-2019ECOM PUR/PAYTM/Noida/150119/10:25
# 14                                             nannan
# 15                                             nannan
# 16                                      17-01-2019nan
# 17                                             nannan
# 18                                             nannan
# 19  17-01-2019IMPS/P2A/901713217651/62246765390SBI...
# 20                                             nannan
# 21                                             nannan
# 22        21-01-2019EDC/00054-00054-/M037011032984700
# 23                                             nannan
# 24                                             nannan
# 25        22-01-2019EDC/00055-00055-/M037011032984700
# 26                                             nannan
# 27                                             nannan
# 28   22-01-2019ECOM PUR/PAYTM/1204770770/220119/13:26
# 29                                             nannan
# 30                                             nannan
# 31                                      23-01-2019nan
# 32                                             nannan
# 33                                             nannan
# 34                                      23-01-2019nan
# 35                                             nannan
# 36                                             nannan
# 37    24-01-2019ECOM PUR/PTM*PAYTM/NOIDA/240119/17:50
# 38                                             nannan
# 39                                             nannan
# 40        28-01-2019EDC/00056-00056-/M037011032984700
# 41                                             nannan
# 42                                             nannan
# 43                                      28-01-2019nan
# 44                                             nannan

# %%
tmp1.to_csv("tmp1.csv", index=0)

# %%
idx= c for c in tmp1[tmp1.apply(lambda row: row.astype(str).str.lower().str.contains('nan').any(), axis=1) ==True].index
# Out:
#   File "<ipython-input-85-26938af588b8>", line 1
#     idx= c for c in tmp1[tmp1.apply(lambda row: row.astype(str).str.lower().str.contains('nan').any(), axis=1) ==True].index
#              ^
# SyntaxError: invalid syntax

# %%
tmp1['flag']=tmp1['flag'].apply(lambda row : np.nan if 'nan' in row else row)

# %%
tmp1.to_csv("tmp11.csv", index=0)
